# %%
import pandas as pd
import requests
import json
offset_ = 0
limit_ = 100
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
objects_data.get('data').get('list')[0]
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]
objids[:10]
def load_one(objids): 
    url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{objids}' 
    res = requests.get(url) 
    objects_data = res.json() 
    return objects_data['data']
a = [] 
for i in objids: 
    a.append(load_one(i))
df_detal = pd.json_normalize(a)
df_detal
# Out:
#        id    pdId  region                          address  objElemLivingCnt  \
# 0   29679  124647      61                       г Таганрог                18
# 1   13398   28141      72  г Тюмень, ул Профсоюзная, д. 56                43
# 2   13399   28141      72  г Тюмень, ул Профсоюзная, д. 56                 0
# 3   13397   28141      72  г Тюмень, ул Профсоюзная, д. 56                65
# 4   13383   28105      72                         г Тюмень                68
# ..    ...     ...     ...                              ...               ...
# 95  33230   77853      77                д Зверево, д. 136                23
# 96  33232   77853      77                д Зверево, д. 138                23
# 97  33096   77853      77                  д Зверево, д. 2                75
# 98  33134   77853      77                 д Зверево, д. 40                75
# 99  33144   77853      77                 д Зверево, д. 50                23
#
#    objReady100PercDt wallMaterialShortDesc   objLkFinishTypeDesc  \
# 0         2020-03-31                Другое              Под ключ
# 1         2024-12-31                Другое           Без отделки
# 2         2024-12-31                Другое           Без отделки
# 3         2024-12-31                Другое           Без отделки
# 4         2022-12-31                Другое  По желанию заказчика
# ..               ...                   ...                   ...
# 95        2022-12-31                Другое           Без отделки
# 96        2022-12-31                Другое           Без отделки
# 97        2023-09-30                Другое           Без отделки
# 98        2023-09-30                Другое           Без отделки
# 99        2024-03-31                Другое           Без отделки
#
#    objLkFreePlanDesc  objElemParkingCnt  ...  \
# 0               Есть                  0  ...
# 1                Нет                  0  ...
# 2                Нет                125  ...
# 3                Нет                  0  ...
# 4               Есть                 31  ...
# ..               ...                ...  ...
# 95               Нет                  0  ...
# 96               Нет                  0  ...
# 97               Нет                  0  ...
# 98               Нет                  0  ...
# 99               Нет                  0  ...
#
#     developer.bankruptStage.bankruptStageDesc  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ..                                        ...
# 95                                        NaN
# 96                                        NaN
# 97                                        NaN
# 98                                        NaN
# 99                                        NaN
#
#    developer.bankruptStage.bankruptLawUrl developer.orgBankruptMsgDttm  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                                     NaN                          NaN
# 3                                     NaN                          NaN
# 4                                     NaN                          NaN
# ..                                    ...                          ...
# 95                                    NaN                          NaN
# 96                                    NaN                          NaN
# 97                                    NaN                          NaN
# 98                                    NaN                          NaN
# 99                                    NaN                          NaN
#
#    metro.id metro.name metro.line  metro.color  metro.time metro.isWalk  \
# 0       NaN        NaN        NaN          NaN         NaN          NaN
# 1       NaN        NaN        NaN          NaN         NaN          NaN
# 2       NaN        NaN        NaN          NaN         NaN          NaN
# 3       NaN        NaN        NaN          NaN         NaN          NaN
# 4       NaN        NaN        NaN          NaN         NaN          NaN
# ..      ...        ...        ...          ...         ...          ...
# 95      NaN        NaN        NaN          NaN         NaN          NaN
# 96      NaN        NaN        NaN          NaN         NaN          NaN
# 97      NaN        NaN        NaN          NaN         NaN          NaN
# 98      NaN        NaN        NaN          NaN         NaN          NaN
# 99      NaN        NaN        NaN          NaN         NaN          NaN
#
#    metro.colors
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 95          NaN
# 96          NaN
# 97          NaN
# 98          NaN
# 99          NaN
#
# [100 rows x 109 columns]
