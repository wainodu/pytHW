# %%
import pandas as pd
import requests
offset_ = 1
limit_ = 100
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={offset_}&limit={limit_}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()
objects_data.get('data').get('list')[0]
objects_list = objects_data.get('data').get('list')
objids = [x.get('objId') for x in objects_list]
objids[:10]
# Out:
# [13398, 13399, 13397, 13383, 13391, 36912, 44076, 27476, 10891, 39176]

# %%
list = [13398, 13399, 13397, 13383, 13391, 36912, 44076, 27476, 10891, 39176]
i = 0
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/{list[i]}'
res = requests.get(url)
res.json()
# Out:
# {'data': {'id': 13398,
#   'pdId': 28141,
#   'developer': {'devId': 306,
#    'devShortCleanNm': '2МЕН ГРУПП',
#    'devShortNm': '2МЕН ГРУПП',
#    'devFullCleanNm': '2МЕН ГРУПП',
#    'problObjCnt': 0,
#    'buildObjCnt': 5,
#    'comissObjCnt': 0,
#    'regRegionDesc': 'Тюменская область',
#    'devPhoneNum': '+7(345)279-18-88',
#    'devSite': '2mengroup.ru',
#    'devEmail': 'info@2mengroup.ru',
#    'devInn': '7701651356',
#    'devOgrn': '1067746424899',
#    'devKpp': '720301001',
#    'devLegalAddr': 'Тюменская область, город Тюмень, улица Комсомольская дом 75/5',
#    'devFactAddr': 'Тюменская область, город Тюмень, улица Комсомольская 75/5',
#    'lastRpdId': 632865,
#    'fundGuarantyFlg': 1,
#    'devOrgRegRegionCd': 72,
#    'devEmplMainFullNm': 'Киселев Сергей Михайлович',
#    'developerGroupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'companyGroupId': 5776,
#    'objGuarantyEscrowFlg': 0,
#    'govFundFlg': 0},
#   'region': 72,
#   'address': 'г Тюмень, ул Профсоюзная, д. 56',
#   'floorMin': 7,
#   'floorMax': 10,
#   'objElemLivingCnt': 43,
#   'objReady100PercDt': '2024-12-31',
#   'wallMaterialShortDesc': 'Другое',
#   'objLkFinishTypeDesc': 'Без отделки',
#   'objLkFreePlanDesc': 'Нет',
#   'objElemParkingCnt': 0,
#   'objSquareLiving': 4812.98,
#   'rpdNum': '72-000097',
#   'rpdPdfLink': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/55f1b383-f682-4365-9238-e4a27c343263',
#   'rpdIssueDttm': '07-09-2022 15:20',
#   'objLkLatitude': '57.1519',
#   'objLkLongitude': '65.5544',
#   'objCompensFundFlg': 0,
#   'objProblemFlg': 0,
#   'objLkClassDesc': 'Элитный',
#   'loadDttm': '29-09-2022 01:27',
#   'photoRenderDTO': [{'objId': 13398,
#     'pdId': 28141,
#     'rpdId': 632865,
#     'devId': 306,
#     'ordNum': 1,
#     'objRenderPhotoSize': 1325881,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/02b88db9-bdd0-4b77-b652-32578b277f6b',
#     'objRenderPhotoDttm': '12-05-2021 16:52',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': 'IMG_20210512_093624.jpg',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Жилое',
#     'knFlg': 1,
#     'loadDttm': '29-09-2022 01:10'},
#    {'objId': 13398,
#     'pdId': 28141,
#     'rpdId': 632865,
#     'devId': 306,
#     'ordNum': 2,
#     'objRenderPhotoSize': 1383679,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/bf3be0fd-4fbf-43e5-9fc8-878e2572c54b',
#     'objRenderPhotoDttm': '12-05-2021 16:52',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': 'IMG_20210512_0936261.jpg',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Жилое',
#     'knFlg': 1,
#     'loadDttm': '29-09-2022 01:10'},
#    {'objId': 13398,
#     'pdId': 28141,
#     'rpdId': 632865,
#     'devId': 306,
#     'ordNum': 3,
#     'objRenderPhotoSize': 101323,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/9dce7b87-2eec-4a1d-9c95-637915fde79f',
#     'objRenderPhotoDttm': '17-09-2021 14:54',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': 'IMG_8196.JPG',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Жилое',
#     'knFlg': 1,
#     'loadDttm': '29-09-2022 01:10'},
#    {'objId': 13398,
#     'pdId': 28141,
#     'rpdId': 632865,
#     'devId': 306,
#     'ordNum': 4,
#     'objRenderPhotoSize': 80019,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/547ca489-819a-4f0f-b0d5-0313a893bf02',
#     'objRenderPhotoDttm': '17-09-2021 14:54',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': 'IMG_81971.JPG',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Жилое',
#     'knFlg': 1,
#     'loadDttm': '29-09-2022 01:10'},
#    {'objId': 13398,
#     'pdId': 28141,
#     'rpdId': 632865,
#     'devId': 306,
#     'ordNum': 5,
#     'objRenderPhotoSize': 322146,
#     'objRenderPhotoUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/5752d0b6-aeba-4914-877c-110ce07da450',
#     'objRenderPhotoDttm': '20-01-2022 10:36',
#     'objRenderPhotoHiddenFlg': 0,
#     'objRenderPhotoNm': 'IMG_8924.JPG',
#     'objReadyDesc': 'Строится',
#     'objBuildTypeShortDesc': 'Жилое',
#     'knFlg': 1,
#     'loadDttm': '29-09-2022 01:10'}],
#   'objGuarantyEscrowFlg': 0,
#   'objectType': 'normal',
#   'miniUrl': 'https://xn--80az8a.xn--d1aqf.xn--p1ai/api/ext/file/ddfe3c88-edc4-4b78-b1b5-68f8ea2877fc',
#   'residentialBuildings': 1,
#   'newBuildingId': 37165,
#   'objFloorCnt': 10,
#   'objFlatCnt': 43,
#   'objFlatSq': '4812.98',
#   'objNonlivElemCnt': 48,
#   'quartography': {'objLivElem1KCnt': 0,
#    'objLivElem2KCnt': 11,
#    'objLivElem3KCnt': 19,
#    'objLivElem4KCnt': 13,
#    'objLivElemCnt': 43,
#    'objLivElemEntrCnt': 3,
#    'objLivElemEntrFloorAvg': 3},
#   'objStatus': 0,
#   'isAvailableWantLiveHere': True,
#   'objTransferPlanDt': '28-02-2025 12:00',
#   'objLivCeilingHeight': '2,96',
#   'objInfrstrBicycleLaneFlg': 0,
#   'objInfrstrPlaygrndCnt': 1,
#   'objInfrstrSportGroundCnt': 1,
#   'objInfrstrTrashAreaCnt': 1,
#   'objInfrstrObjPrkngCnt': 4,
#   'objInfrstrNotObjPrkngCnt': 15,
#   'objInfrstrRampFlg': 1,
#   'objInfrstrCurbLoweringFlg': 1,
#   'objElevatorWheelchairCnt': 0,
#   'objElevatorPassengerCnt': 3,
#   'objElevatorCargoCnt': 3,
#   'objElevatorCargoPassengerCnt': 6,
#   'soldOutPerc': 1.0,
#   'objPriceAvg': 47886,
#   'generalContractorNm': 'ООО Транспромжилстрой-2005 (ИНН: 7204097730)',
#   'nonlivFirstFloor': 0,
#   'objectTransportInfo': [],
#   'conclusion': False,
#   'objLkSaleDepEmail': 'info@2mengroup.ru',
#   'objGreenHouseFlg': 0,
#   'objEnergyEffShortDesc': 'B',
#   'infrastructureIndexValue': 10},
#  'errcode': '0'}
